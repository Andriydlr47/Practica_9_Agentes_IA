# %%
import pandas as pd

# %%
df = pd.read_csv("RAG/vias_espania_8anu.csv")
# Out:
# C:\Users\elpollitolive47\AppData\Local\Temp\ipykernel_24356\248341609.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("RAG/vias_espania_8anu.csv")

# %%
df['lat'].isna().sum()
# Out:
# np.int64(0)

# %%
df.dropna(subset=['lat', 'lon'], inplace=True)

# %%
df.to_csv("RAG/vias_espania_8anu_limpio.csv", index=False)
